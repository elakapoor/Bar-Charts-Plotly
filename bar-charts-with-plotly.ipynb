# %% [markdown]
# <a href="https://www.kaggle.com/elakapoor/bar-charts-with-plotly?scriptVersionId=89848115" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import plotly.express as px

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/geeksforgeeks-articles/articles.csv

# %%
df = pd.read_csv("/kaggle/input/geeksforgeeks-articles/articles.csv")
df.head()
# Out:
#                                           title         author_id  \
# 0        5 Best Practices For Writing SQL Joins       priyankab14
# 1                  Foundation CSS Dropdown Menu  ishankhandelwals
# 2  Top 20 Excel Shortcuts That You Need To Know       priyankab14
# 3                     Servlet – Fetching Result   nishatiwari1719
# 4                              Suffix Sum Array          rohit768
#
#    last_updated                                               link category
# 0  21 Feb, 2022  https://www.geeksforgeeks.org/5-best-practices...     easy
# 1  20 Feb, 2022  https://www.geeksforgeeks.org/foundation-css-d...     easy
# 2  17 Feb, 2022  https://www.geeksforgeeks.org/top-20-excel-sho...     easy
# 3  17 Feb, 2022  https://www.geeksforgeeks.org/servlet-fetching...     easy
# 4  21 Feb, 2022    https://www.geeksforgeeks.org/suffix-sum-array/     easy

# %%
df["year"] = df["last_updated"].str.split(",", expand = True).get(1)
df["date_month"] = df["last_updated"].str.split(",", expand = True).get(0)
df["month"] = df["date_month"].str.split(" ", expand = True).get(1)
df["date"] = df["date_month"].str.split(" ", expand = True).get(0)

# %%
df.drop(["link"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                           title         author_id  \
# 0        5 Best Practices For Writing SQL Joins       priyankab14
# 1                  Foundation CSS Dropdown Menu  ishankhandelwals
# 2  Top 20 Excel Shortcuts That You Need To Know       priyankab14
# 3                     Servlet – Fetching Result   nishatiwari1719
# 4                              Suffix Sum Array          rohit768
#
#    last_updated category   year date_month month date
# 0  21 Feb, 2022     easy   2022     21 Feb   Feb   21
# 1  20 Feb, 2022     easy   2022     20 Feb   Feb   20
# 2  17 Feb, 2022     easy   2022     17 Feb   Feb   17
# 3  17 Feb, 2022     easy   2022     17 Feb   Feb   17
# 4  21 Feb, 2022     easy   2022     21 Feb   Feb   21

# %%
df.shape
# Out:
# (34574, 8)

# %%
null_index = df.isnull().sum().index
null_values = df.isnull().sum().values
null_values
# Out:
# array([  0,  19,  18,   0, 114,  18, 114,  18])

# %% [markdown]
# # Basic Charts

# %%
# bar charts
fig = px.bar(x = null_index, y = null_values) # providing x and y values

fig.update_layout(
        xaxis_title = "Column Name", # x-axis label
        yaxis_title = "Missing Values", # y-axis label
        title = "Total missing values per column") # bar plot title
 
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="4892df40-eb2c-46b3-91a1-abc59de9baac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4892df40-eb2c-46b3-91a1-abc59de9baac")) {                    Plotly.newPlot(                        "4892df40-eb2c-46b3-91a1-abc59de9baac",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["title","author_id","last_updated","category","year","date_month","month","date"],"xaxis":"x","y":[0,19,18,0,114,18,114,18],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3 ...

# %% [markdown]
# Conclusions:
# 1. 19 author_id are missing
# 2. last_updated have 18 missing values
# 3. date extracted from the last_updated also have 18 missing values
# 4. Column year and month have 114 missing values. These columns are extracted from the last_updated column.

# %%
df[df['year'].isna()]
# Out:
#                                                    title      author_id  \
# 20     Must Do Coding Questions for Product Based Com...  GeeksforGeeks
# 152    Get Hired With GeeksforGeeks and Win Exciting ...  GeeksforGeeks
# 617    Recently Asked Interview Questions in Product ...  GeeksforGeeks
# 654    100 Days of Code – A Complete Guide For Beginn...    anuupadhyay
# 711    Be a Part of GeeksforGeeks YouTube World – Mor...  GeeksforGeeks
# ...                                                  ...            ...
# 31290                  Brent’s Cycle Detection Algorithm     Surya Priy
# 31348                                       Sparse Table    pawan_asipu
# 31567   Number Theory (Interesting Facts and Algorithms)  GeeksforGeeks
# 31570                          Magic Square | Even Order  GeeksforGeeks
# 31596                               Bidirectional Search  GeeksforGeeks
#
#       last_updated category  year date_month month    date
# 20          Medium     easy  None     Medium  None  Medium
# 152           Easy     easy  None       Easy  None    Easy
# 617         Medium     easy  None     Medium  None  Medium
# 654         Medium     easy  None     Medium  None  Medium
# 711         Medium     easy  None     Medium  None  Medium
# ...            ...      ...   ...        ...   ...     ...
# 31290         Hard     hard  None       Hard  None    Hard
# 31348         Hard     hard  None       Hard  None    Hard
# 31567         Hard     hard  None       Hard  None    Hard
# 31570         Hard     hard  None       Hard  None    Hard
# 31596         Hard     hard  None       Hard  None    Hard
#
# [114 rows x 8 columns]

# %%
# The above shows that last_updated column have worng entries
# let us drop these rows
df.dropna(subset=['year'], inplace = True)

# %%
df.shape
# Out:
# (34460, 8)

# %%
df.isnull().sum()
# Out:
# title           0
# author_id       5
# last_updated    0
# category        0
# year            0
# date_month      0
# month           0
# date            0
# dtype: int64

# %%
df[df["author_id"].isna()]
# Out:
#                                               title author_id  last_updated  \
# 8234                                        Puzzles       NaN  23 Jul, 2018
# 14665                     JavaTuples | Introduction       NaN  16 Sep, 2021
# 15073                HTML5 | Mathematical operators       NaN  03 Dec, 2018
# 27434  GATE | GATE-CS-2015 (Mock Test) | Question 2       NaN  08 Nov, 2021
# 33812                  UwU text convertor in Python       NaN  07 Aug, 2021
#
#       category   year date_month month date
# 8234      easy   2018     23 Jul   Jul   23
# 14665    basic   2021     16 Sep   Sep   16
# 15073    basic   2018     03 Dec   Dec   03
# 27434   medium   2021     08 Nov   Nov   08
# 33812   expert   2021     07 Aug   Aug   07

# %%
df.dropna(subset=['author_id'], inplace = True)

# %%
df.shape
# Out:
# (34455, 8)

# %%
df.isnull().sum()
# Out:
# title           0
# author_id       0
# last_updated    0
# category        0
# year            0
# date_month      0
# month           0
# date            0
# dtype: int64

# %%
# Now our data frame is clean 
# We do not have any null values
# Let us now check the dtype of all the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34455 entries, 0 to 34573
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         34455 non-null  object
#  1   author_id     34455 non-null  object
#  2   last_updated  34455 non-null  object
#  3   category      34455 non-null  object
#  4   year          34455 non-null  object
#  5   date_month    34455 non-null  object
#  6   month         34455 non-null  object
#  7   date          34455 non-null  object
# dtypes: object(8)
# memory usage: 2.4+ MB

# %%
#dtype of the year and date should be integer type
df["year"] = df["year"].astype(int)
df["date"] = df["date"].astype(int)

# %%
# Now our dtype is also correct
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34455 entries, 0 to 34573
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         34455 non-null  object
#  1   author_id     34455 non-null  object
#  2   last_updated  34455 non-null  object
#  3   category      34455 non-null  object
#  4   year          34455 non-null  int64
#  5   date_month    34455 non-null  object
#  6   month         34455 non-null  object
#  7   date          34455 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 2.4+ MB

# %%
df.author_id.value_counts()
# the articles written by GeeksforGeeks are way too large than other authors articles
# Out:
# GeeksforGeeks        11932
# ManasChhabra2          317
# Striver                261
# manjeet_04             246
# Chinmoy Lenka          191
#                      ...
# KritikaSharma21          1
# RatulSarkar1             1
# shivamyadav17            1
# ksinghshubh              1
# sandeep tadepalli        1
# Name: author_id, Length: 5583, dtype: int64

# %%
# Most frequent author
author_name = df.author_id.value_counts().index[1:11]
author_count = df.author_id.value_counts().values[1:11]
fig = px.histogram(x = author_name, y = author_count)

fig.update_layout(
        xaxis_title = "Author Name",
        yaxis_title = "Article Count",
        title = "<b>Total article per author</b>", # making the title bold
        plot_bgcolor = "#ECECEC")  # changing plot background color

fig.show()
# Out:
# <div>                            <div id="fadb1b19-9bf6-4a48-bdf0-197cfaa268aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fadb1b19-9bf6-4a48-bdf0-197cfaa268aa")) {                    Plotly.newPlot(                        "fadb1b19-9bf6-4a48-bdf0-197cfaa268aa",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["ManasChhabra2","Striver","manjeet_04","Chinmoy Lenka","pawan_asipu","sarthak_ishu11","anuupadhyay","Shubrodeep Banerjee","ankita_saini","MKS075"],"xaxis":"x","y":[317,261,246,191,155,151,146,143,125,121],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"ty ...

# %% [markdown]
# Conclusions:
# 1. Above graph shows the top 11 authors excluding first.

# %%
# check the status of top 10 author other GeeksforGeeks
df_author_other = []

for i in author_name:
    df_new = df[df.author_id == i].groupby(["author_id", "category",
                "year"]).size().reset_index(name = "count").sort_values(by = "count",
                                                            ascending = False)
    df_author_other.append(df_new)
    
frame_other = pd.concat(df_author_other)
    
frame_other.head()
# Out:
#         author_id category  year  count
# 0   ManasChhabra2    basic  2019    135
# 2   ManasChhabra2    basic  2021    131
# 1   ManasChhabra2    basic  2020     14
# 3   ManasChhabra2    basic  2022     13
# 15  ManasChhabra2   medium  2021      7

# %%
# grouped bars

fig = px.bar(frame_other, x = "author_id", y = "count", color = "category",
             barmode='group')

# automatic color according to the category 


fig.update_layout(
        title = "<b>Distribution of articles published by GeeksforGeeks over year</b>",
        plot_bgcolor = "#ECECEC")


fig.show()
# Out:
# <div>                            <div id="3f332971-8526-42aa-adfc-8924d4afce17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f332971-8526-42aa-adfc-8924d4afce17")) {                    Plotly.newPlot(                        "3f332971-8526-42aa-adfc-8924d4afce17",                        [{"alignmentgroup":"True","hovertemplate":"category=basic<br>author_id=%{x}<br>count=%{y}<extra></extra>","legendgroup":"basic","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"basic","offsetgroup":"basic","orientation":"v","showlegend":true,"textposition":"auto","x":["ManasChhabra2","ManasChhabra2","ManasChhabra2","ManasChhabra2","Striver","Striver","Striver","Striver","Striver","manjeet_04","manjeet_04","manjeet_04","manjeet_04","manjeet_04","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","pawan_asipu","pawan_asipu","pawan_asipu","pawan_asipu","pawan_asipu","sarthak_ishu11","sarthak_ishu11","sarthak_ishu11","sarthak_ishu11","sarthak_ishu11","anuupadhyay","anuupadhyay","anuupadhyay","Shubrodeep Banerjee","Shubrodeep Banerjee","Shubrodeep Banerjee","Shubrodeep Banerjee","Shubrodeep Banerjee","ankita_saini","ankita_saini","ankita_saini","ankita_saini","ankita_saini","MKS075","MKS075","MKS075","MKS075"],"xaxis":"x","y":[135,131,14,13,47,8,8,7,1,30,27,25,7,2,33,30,16,10,5,4,24,3,3,3,1,25,8,5,2,1,22,9,3,50,31,23,6,2,24,12,11,4,2,24,12,12,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=medium<br>author_id=%{x}<br>count=%{y}<extra></extra>","legendgroup":"medium","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"medium","offsetgroup":"medium","orientation":"v","showlegend":true,"textposition":"auto","x":["ManasChhabra2","ManasChhabra2","ManasChhabra2","ManasChhabra2","Striver","Striver","Striver","Striver","Striver","manjeet_04","manjeet_04","manjeet_04","manjeet_04","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","pawan_asipu","pawan_asipu","pawan_asipu","pawan_asipu","sarthak_ishu11","sarthak_ishu11","sarthak_ishu11","sarthak_ishu11","sarthak_ishu11","anuupadhyay","anuupadhyay","anuupadhyay","anuupadhyay","Shubrodeep Banerjee","Shubrodeep Banerjee","Shubrodeep Banerjee","Shubrodeep Banerjee","ankita_saini","ankita_saini","ankita_saini","ankita_saini","MKS075","MKS075","MKS075"],"xaxis":"x","y":[7,3,2,1,69,15,4,1,1,17,15,12,5,10,8,6,3,2,45,4,2,2,15,6,3,1,1,21,18,5,4,6,2,1,1,10,10,2,1,5,5,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=easy<br>author_id=%{x}<br>count=%{y}<extra></extra>","legendgroup":"easy","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"easy","offsetgroup":"easy","orientation":"v","showlegend":true,"textposition":"auto","x":["ManasChhabra2","ManasChhabra2","ManasChhabra2","ManasChhabra2","Striver","Striver","Striver","Striver","manjeet_04","manjeet_04","manjeet_04","manjeet_04","manjeet_04","manjeet_04","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","Chinmoy Lenka","pawan_asipu","pawan_asipu","pawan_asipu","pawan_asipu","sarthak_ishu11","sarthak_ishu11","sarthak_ishu11","sarthak_ishu11","sarthak_ishu11","anuupadhyay","anuupadhyay","anuupadhyay","anuupadhyay","Shubrodeep Banerjee","Shubrodeep Banerjee","Shubrodeep Banerjee","Shubrodeep Banerjee","Shubrodeep Banerjee","ankita_saini","ankita_saini","ankita_saini","ankita_saini","ankita_saini","MKS075","MKS075","MKS075","MKS075"],"xaxis":"x","y":[3,1,1,1,57,6,5,2,22,19,19,8,4,1,17,16,12,4,3,3,31,3,2,1,43,18,12,2,2,24,10,4,2,11,2,1,1,1,15,7,5,2,1,23,14,7,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=expert<br>author_id=%{x}<br>count=%{y}<extra></extra>","legendgroup":"expert","marker":{"color":"#ab63fa","patte ...

# %% [markdown]
# Conclusions:
# 1. ManasChhabra2 published maximum article after GeeksforGeeks
# 2. Basic level article are popular among the above top 11 (excluding first) authors

# %%
# checking the category
df_category = df.groupby("category").size().reset_index(name = "count")
df_category
# Out:
#   category  count
# 0    basic   8127
# 1     easy   9602
# 2   expert   2094
# 3     hard   4223
# 4   medium  10409

# %%
fig = px.bar(df_category, x = "category", y = "count",  text_auto='.2s',
             color_discrete_sequence = ["#ffd514"] * len(df_category))
# providing custom color to the bars in chart
# text indicating the value of the bar

fig.update_layout(
        title = "<b> Distribution of Category </b>",
        plot_bgcolor = "#ECECEC",
        xaxis={'categoryorder':'total descending'} # arranging the bars in descending order
        )
fig.show()

# Note that we did not provide the x-axis and y-axis label.
# The column name is the name for the x axis and y axis label
# Out:
# <div>                            <div id="705ddb6b-a72e-4b75-9a65-aa6ac4434cc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("705ddb6b-a72e-4b75-9a65-aa6ac4434cc5")) {                    Plotly.newPlot(                        "705ddb6b-a72e-4b75-9a65-aa6ac4434cc5",                        [{"alignmentgroup":"True","hovertemplate":"category=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#ffd514","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["basic","easy","expert","hard","medium"],"xaxis":"x","y":[8127,9602,2094,4223,10409],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d" ...

# %% [markdown]
# Conclusions:
# 1. Maximum articles are of medium category
# 2. Expert level articles nearly 5 times less that medium level article

# %%
df_month = df.groupby(["year","month"]).size().reset_index(name = "count")
df_month.head()
# Out:
#    year month  count
# 0  2010   Nov      1
# 1  2011   Apr      1
# 2  2012   Oct      5
# 3  2013   Feb     48
# 4  2013   Jan     20

# %%
# stack bars

fig = px.bar(df_month, x = "month", y = "count", color = "year")
fig.update_layout(
        title = "<b>Count of Yearly Articles Published per Month</b>",
        plot_bgcolor = "#ECECEC",
        xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="fb9bb366-f88e-48bb-823d-a0903051a62d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb9bb366-f88e-48bb-823d-a0903051a62d")) {                    Plotly.newPlot(                        "fb9bb366-f88e-48bb-823d-a0903051a62d",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>count=%{y}<br>year=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2010,2011,2012,2013,2013,2013,2014,2014,2014,2014,2014,2014,2014,2014,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2022,2022],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Nov","Apr","Oct","Feb","Jan","Mar","Aug","Dec","Feb","Jan","Jul","Nov","Oct","Sep","Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep","Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep","Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep","Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep","Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep","Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep","Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep","Feb","Jan"],"xaxis":"x","y":[1,1,5,48,20,2,9,17,1,1,2,2,11,10,9,26,21,6,10,9,9,7,7,16,33,19,12,20,33,11,37,11,7,18,9,9,16,17,45,116,85,9,22,96,63,71,179,76,114,145,99,232,407,266,131,187,127,144,146,247,231,305,256,512,235,207,332,573,337,176,395,377,303,282,341,391,563,226,265,411,428,216,404,503,460,417,1555,1886,1313,627,516,1534,3089,876,2191,1701,1602,1723,1315,1872],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7 ...

# %% [markdown]
# Conclusions:
# 1. Maximum articles are published in June
# 2. The number of articles published in years 2010-2016 are very less
# 3. The frequency of articles publishing increases from the 2018
# 4. Articles from 2 months of 2022 (January and Febuary) are also present. This means data is recent

# %%
df_author_geek = df[df.author_id == "GeeksforGeeks"].groupby(["author_id", "category",
                "year"]).size().reset_index(name = "count").sort_values(by = "count",
                                                            ascending = False)
df_author_geek.head()
# Out:
#         author_id category  year  count
# 22  GeeksforGeeks     easy  2021   1903
# 52  GeeksforGeeks   medium  2021   1755
# 10  GeeksforGeeks    basic  2021   1222
# 41  GeeksforGeeks     hard  2021    616
# 50  GeeksforGeeks   medium  2019    594

# %%
# grouped bars

fig = px.bar(df_author_geek, x = "year", y = "count", color = "category", barmode='group',
            color_discrete_map= {'basic': '#3C8DD6', 'expert': '#EC2781',
                                "easy":"#008237", "medium":"#FDDA0D", "hard":"#510020"},)
# custom color in bars 

fig.update_layout(
        title = "<b>Distribution of articles published by GeeksforGeeks over year</b>",
        plot_bgcolor = "#ECECEC")


fig.show()
# Out:
# <div>                            <div id="f86c0a67-04f4-4b54-a6e5-aae1808f89db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f86c0a67-04f4-4b54-a6e5-aae1808f89db")) {                    Plotly.newPlot(                        "f86c0a67-04f4-4b54-a6e5-aae1808f89db",                        [{"alignmentgroup":"True","hovertemplate":"category=easy<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"easy","marker":{"color":"#008237","pattern":{"shape":""}},"name":"easy","offsetgroup":"easy","orientation":"v","showlegend":true,"textposition":"auto","x":[2021,2022,2019,2018,2017,2020,2016,2015,2013,2014,2012,2010],"xaxis":"x","y":[1903,488,397,339,305,242,48,46,30,12,3,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=medium<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"medium","marker":{"color":"#FDDA0D","pattern":{"shape":""}},"name":"medium","offsetgroup":"medium","orientation":"v","showlegend":true,"textposition":"auto","x":[2021,2019,2022,2018,2017,2020,2016,2015,2014,2013,2012],"xaxis":"x","y":[1755,594,415,384,327,306,88,74,19,12,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=basic<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"basic","marker":{"color":"#3C8DD6","pattern":{"shape":""}},"name":"basic","offsetgroup":"basic","orientation":"v","showlegend":true,"textposition":"auto","x":[2021,2022,2018,2017,2020,2019,2016,2013,2015,2014,2012,2011],"xaxis":"x","y":[1222,274,218,177,167,159,27,24,15,6,1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=hard<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"hard","marker":{"color":"#510020","pattern":{"shape":""}},"name":"hard","offsetgroup":"hard","orientation":"v","showlegend":true,"textposition":"auto","x":[2021,2019,2018,2022,2020,2017,2015,2016,2014,2013],"xaxis":"x","y":[616,319,179,126,120,120,35,33,15,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=expert<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"expert","marker":{"color":"#EC2781","pattern":{"shape":""}},"name":"expert","offsetgroup":"expert","orientation":"v","showlegend":true,"textposition":"auto","x":[2021,2019,2018,2020,2017,2022,2016,2015,2014],"xaxis":"x","y":[135,48,40,31,14,10,4,2,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...

# %% [markdown]
# Coclusions:
# 1. GeeksforGeeks published many articles in 2021
# 2. Medium and Easy are the most common article category
# 3. Articles at Expert level are very less

# %%
df.head()
# Out:
#                                           title         author_id  \
# 0        5 Best Practices For Writing SQL Joins       priyankab14
# 1                  Foundation CSS Dropdown Menu  ishankhandelwals
# 2  Top 20 Excel Shortcuts That You Need To Know       priyankab14
# 3                     Servlet – Fetching Result   nishatiwari1719
# 4                              Suffix Sum Array          rohit768
#
#    last_updated category  year date_month month  date
# 0  21 Feb, 2022     easy  2022     21 Feb   Feb    21
# 1  20 Feb, 2022     easy  2022     20 Feb   Feb    20
# 2  17 Feb, 2022     easy  2022     17 Feb   Feb    17
# 3  17 Feb, 2022     easy  2022     17 Feb   Feb    17
# 4  21 Feb, 2022     easy  2022     21 Feb   Feb    21

# %%
# distribution of article as per the bi-weekly in 2021
df_year = df.loc[df["year"] == 2021]

bi_week = []
for i in df_year.date:
    if i <= 15:
        bi_week.append(0)
    else:
        bi_week.append(1)
df_year["bi_weekly"] = bi_week
df_year.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                 title          author_id  \
# 46  Unthinkable Solutions Interview Experience | O...      GeeksforGeeks
# 48  Which built-in method returns the calling stri...    mrtwinklesharma
# 50  Amazon Internship Interview Experience | On-Ca...  rashimnarayantiku
# 51  Goldman Sachs Internship Interview Experience ...      GeeksforGeeks
# 52        Spring Boot – CRUD Operations using MongoDB    AmiyaRanjanRout
#
#     last_updated category  year date_month month  date  bi_weekly
# 46  30 Dec, 2021     easy  2021     30 Dec   Dec    30          1
# 48  31 Dec, 2021     easy  2021     31 Dec   Dec    31          1
# 50  28 Dec, 2021     easy  2021     28 Dec   Dec    28          1
# 51  28 Dec, 2021     easy  2021     28 Dec   Dec    28          1
# 52  28 Dec, 2021     easy  2021     28 Dec   Dec    28          1

# %%
df_2021 = df_year.groupby(["month", "bi_weekly"]).size().reset_index(name = "count")
df_2021.head()
# Out:
#   month  bi_weekly  count
# 0   Apr          0    652
# 1   Apr          1    903
# 2   Aug          0    922
# 3   Aug          1    964
# 4   Dec          0    690

# %%
# dividing data into two columns depending on the week they fall
fig = px.bar(df_2021, x = "month", y = "count", facet_col = "bi_weekly",
            color_discrete_sequence = ["#000080"] * len(df_2021))

# adding a mean line to check the distribution
fig.add_hline(y=df_2021["count"].mean(), line_width=2, line_dash="dash", 
              line_color="#FF9933")

fig.update_layout(
    paper_bgcolor = "#ECECEC",
    plot_bgcolor = "#ECECEC",
    autosize = True,
    yaxis = dict(
        title_text = "<b> Count of Articles </b>",
        titlefont = dict(size = 12) # adding font size for y-axis
    ),
    title_text = "<b> Distribution of Articles Bi-Weekly </b>",
    title_font_size = 16, # adding font size to the article
    title_font_color = "black", # adding font color to the article
    title_pad_t = 5, # adding space to the title heading
    title_pad_l = 20 # adding space to the title heading
    )
 
# adding line color, line width, and tick lables to both the axis
fig.update_yaxes(showticklabels = True, showline = True, linewidth = 2, linecolor = "black")
fig.update_xaxes(showticklabels = True, showline = True, linewidth = 2, linecolor = "black")
# Out:
# <div>                            <div id="f06e81f6-8d32-4124-96c1-58af0a5cdbc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f06e81f6-8d32-4124-96c1-58af0a5cdbc8")) {                    Plotly.newPlot(                        "f06e81f6-8d32-4124-96c1-58af0a5cdbc8",                        [{"alignmentgroup":"True","hovertemplate":"bi_weekly=0<br>month=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#000080","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep"],"xaxis":"x","y":[652,922,690,247,231,811,889,362,949,773,814,872],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"bi_weekly=1<br>month=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#000080","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep"],"xaxis":"x2","y":[903,964,623,380,285,723,2200,514,1242,928,788,851],"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3 ...

# %% [markdown]
# Conclusions:
# 1. The orange line shows the mean of the count of articles published in 2021
# 2. Most of the month shows that the articles are equally distributed
# 3. For the month of June we see that the third and fourth week shows too many articles published on the second half
